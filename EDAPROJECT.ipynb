# %% [markdown]
# <a href="https://colab.research.google.com/github/abdulsaad3698/saad/blob/project/EDAPROJECT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    - Hotel Booking

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# This project involves a comprehensive Exploratory Data Analysis (EDA) of hotel booking data with the objective of uncovering meaningful insights that can drive better decision-making in the hospitality industry. The dataset includes bookings from both city and resort hotels, with variables such as booking dates, lead time, stay duration, customer type, market segment, special requests, and cancellation status. Through data cleaning, visualization, and statistical exploration, the analysis identifies patterns in guest behavior, seasonal trends, and key factors contributing to cancellations.
#
# Key findings highlight how lead time, booking source, room type, and special requests impact the likelihood of cancellations. Differences in guest profiles and booking habits between resort and city hotels are also explored. The insights derived from this project can be used to enhance revenue management strategies, implement targeted marketing, reduce cancellations, and improve customer satisfaction. Overall, the analysis provides a data-driven foundation for hotel managers to optimize operations and increase profitability.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here.

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# # **BUSINESS PROBLEM STATEMENT**
#  In the hospitality industry, maintaining optimal occupancy levels and minimizing cancellations are crucial to profitability and guest satisfaction.
#
# The hotel industry faces constant challenges in managing cancellations, understanding guest behavior, and maximizing occupancy. Without clear insights into booking patterns, hotels risk revenue loss and poor customer experience.
#
# This project aims to analyze hotel booking data to uncover trends in guest preferences, seasonal demand, and cancellation factors. By identifying these patterns, hotels can make data-driven decisions to optimize pricing, reduce cancellations, and improve overall efficiency and customer satisfaction.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# # **BUSINESS OBJECTIVE**
# *   Identify factors contributing to booking cancellations to help reduce loss of revenue.
# *  Analyze booking trends across hotel types (City vs. Resort) and peak seasons.
# *  Understand customer behavior and segmentation to tailor marketing strategies.
# *  Detect patterns in lead time, special requests, and stay duration affecting bookings.
# *   Provide data-driven recommendations for optimizing occupancy, pricing, and resource planning.

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# ### Dataset Loading

# %%
path = '/content/drive/MyDrive/Colab Notebooks/Hotel Bookings.csv'

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ### Dataset First View

# %%
df = pd.read_csv(path)
df.head()

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
df.shape

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df.info()

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
len(df[df.duplicated()])

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
print(df.isnull().sum())

# %%
# Visualizing the missing values
sns.heatmap(df.isnull(), cbar=False)

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
#  The dataset contains information about hotel bookings, with each row representing a single booking. It includes a wide range of attributes related to the booking, guest, and hotel stay.
#
#  This dataset appears well-suited for analyzing customer behavior, identifying factors contributing to cancellations (churn), and potentially building predictive models.
#
#  The above dataset has 119390  rows and 32 columns. There are no mising values and duplicate values in the dataset.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
df.columns

# %%
# Dataset Describe
df.describe()

# %% [markdown]
# ### Variables Description

# %% [markdown]
# **hotel:** Type of hotel (e.g., Resort Hotel).
#
# **is_canceled:** Whether the booking was canceled (0 = No, 1 = Yes). This is a key target variable for churn analysis.
#
# **lead_time:** Number of days between the booking date and the arrival date.
#
# **arrival_date_year:** Year of arrival date.
#
# **arrival_date_month:** Month of arrival date.
#
# **arrival_date_week_number:** Week number of arrival date.
#
# **arrival_date_day_of_month:** Day of the month of arrival date.
#
# **stays_in_weekend_nights:** Number of weekend nights (Saturday or Sunday) the guest stayed or booked to stay.
#
# **stays_in_week_nights:** Number of week nights (Monday to Friday) the guest stayed or booked to stay.
#
# **adults:** Number of adults.
#
# **children:** Number of children.
#
# **babies:** Number of babies.
#
# **meal:** Type of meal booked (e.g., BB - Bed & Breakfast, HB - Half Board, FB - Full Board, SC - Self-catering).
#
# **country:** Country of origin of the guest.
#
# **market_segment:** Market segment designation (e.g., Online TA, Corporate, Direct).
#
# **distribution_channel:** Booking distribution channel (e.g., Direct, Corporate, TA/TO - Travel Agent/Tour Operator).
#
# **is_repeated_guest:** Whether the guest is a repeated guest (0 = No, 1 = Yes).
#
# **previous_cancellations:** Number of previous bookings that were canceled by the customer prior to the current booking.
#
# **previous_bookings_not_canceled:** Number of previous bookings not canceled by the customer prior to the current booking.
#
# **reserved_room_type:** Code of room type reserved.
#
# **assigned_room_type:** Code of room type assigned.
#
# **booking_changes:** Number of changes made to the booking.
#
# **deposit_type:** Type of deposit made (e.g., No Deposit, Non Refund, Refundable).
#
# **agent:** ID of the travel agency that made the booking.
#
# **company:** ID of the company/entity that made the booking or responsible for paying the booking.
#
# **days_in_waiting_list:** Number of days the booking was in the waiting list.
#
# **customer_type:** Type of customer (e.g., Transient, Contract, Group, Transient-Party).
#
# **adr:** Average Daily Rate (average price per day).
#
# **required_car_parking_spaces:** Number of car parking spaces required by the customer.
#
# **total_of_special_requests:** Number of special requests made by the customer.
#
# **reservation_status:** Last reservation status (Canceled, Check-Out, No-Show).
#
# **reservation_status_date**: Date at which the last status was set.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
for i in df.columns.tolist():
  print("No. of unique values in ",i,"is",df[i].nunique(),".")

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
print("No. of customers cancellations   : -",len(df[df['is_canceled']==True]))
# Assigning is_canceled data to variable df_canceled
df_canceled=df[(df['is_canceled']==True)]

# %%
# is_canceled data groupby country Wise
pd.DataFrame(df.groupby('country')['is_canceled'].value_counts().reset_index(name="Count"))

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code
# Chart - 1 visualization code
# Dependant Column Value Counts
print(df.is_canceled.value_counts())
print(" ")
# Dependant Variable Column Visualization
df['is_canceled'].value_counts().plot(kind='pie',
                              figsize=(15,6),
                               autopct="%1.1f%%",
                               startangle=90,
                               shadow=True,
                               labels=['Not cancelled(%)','cancelled(%)'],
                               colors=['skyblue','red'],
                               explode=[0,0]
                              )

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A pie chart expresses a part-to-whole relationship in your data. It's easy to explain the percentage comparison through area covered in a circle with different colors. Where differenet percentage comparison comes into action pie chart is used frequently. So, I used Pie chart and which helped me to get the percentage comparision of the dependant variable.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code
# Chart - 2 visualization code
# Showing Average True Churn Percentage state wise
# Showing top 10 churned state
print((df.groupby(['customer_type'])['is_canceled'].mean()*100).sort_values(ascending = False).reset_index(name="Average cancel %").head(10))
print(" ")

# State vs. average true churn percantage visualization code
# Vizualizing top 10 churned state
plt.rcParams['figure.figsize'] = (12, 7)
color = plt.cm.copper(np.linspace(0, 0.5, 20))
((df.groupby(['customer_type'])['is_canceled'].mean())*100).sort_values(ascending = False).head(10).plot.bar(color = ['violet','indigo','b','g','y','orange','r'])
plt.title(" customer_type with more cancellation", fontsize = 20)
plt.xlabel('customer_type', fontsize = 15)
plt.ylabel('percentage', fontsize = 15)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# Answer Here.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# Write the conclusion here.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
